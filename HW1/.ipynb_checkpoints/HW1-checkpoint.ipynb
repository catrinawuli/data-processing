# %%
#import two packages for reading and ploting CSV files.
import pandas as pd
import matplotlib.pyplot as plt 

# download a csv file and read it from web: https://www.stats.govt.nz/large-datasets/csv-files-for-download/
business_data = pd.read_csv(r"C:\Users\catri\OneDrive\文档\LIWU\HW1\international-trade-june-2023-quarter\output_csv_full.csv")
business_data["value_rescale"] = round(business_data["value"]/10000,1)
business_data.head()

business_data.plot()
plt.show()
